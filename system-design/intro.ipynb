# %% [markdown]
# # 🎯 Сбор требований к системе и расчет нагрузки
#
# ## Зачем считать нагрузки?
#
# На собеседовании можно растеряться. В таком случае наличие стандартного плана действий поможет справиться со стрессом и начать действовать.
#
# ### ⚠️ Риски при сборе требований
#
# Во время сбора требований вы можете:
# - ❌ **Загнать себя в ловушку** — записать что-то невыполнимое
# - ✅ **Сделать правильно** — обозначить ограниченный скоуп для интервью
#
# ---
#
# > 💡 **Совет для System Design интервью:**
# > Вы должны **лидировать** — вести партнера (собеседующего).
# > В идеале: интервьюер задает вопрос, а вы в виде монолога объясняете свои действия на несколько шагов вперед.
#
# ---
#
# ### 🏢 В реальной жизни
#
# Этап сбора требований и расчета нагрузки — **самый нервный**:
# - **Инженер** должен понять, сколько ресурсов требуется
# - **Менеджер** должен определить необходимый бюджет

# %% [markdown]
# # 📐 Высокоуровневый дизайн
#
# После сбора требований и расчета нагрузки приходит время **высокоуровнево изобразить систему**.
#
# ## ⚠️ Важно
#
# Часто люди начинают вдаваться в подробности уже на этом этапе, но **так лучше не делать**.
# Указав основные компоненты, уточните у собеседующего: согласен ли он с дизайном или есть вопросы.
#
# ---
#
# ### 🏢 В реальной жизни
#
# Выделение основных компонент позволяет понять:
#
# | Вопрос | Зачем это нужно |
# |--------|----------------|
# | Есть ли люди, способные выполнить проект? | Оценка текущих компетенций команды |
# | Есть ли все необходимое для компонент? | Проверка доступности инфраструктуры |
# | Нужны ли дополнительные ресурсы? | Планирование headcount и бюджета |

# %% [markdown]
# # 🗄️ Выбор подходящих баз данных
#
# Описав общие концепции и компоненты, пора углубиться в частности.
#
# ## 🎤 На интервью
#
# Данному шагу уделяют меньше внимания — достаточно просто указать, какую базу вы бы хотели видеть.
#
# ---
#
# ## 🏢 В реальной жизни
#
# > ⚠️ **Важно:** Нельзя просто так взять и выбрать любую из существующих БД!
#
# ### Пример
#
# Если в вашей компании всю жизнь работали с **PostgreSQL**, вряд ли можно просто выбрать **Cassandra** — нет людей, которые могут ее поддерживать и использовать.
#
# ### Практический подход
#
# ```
# Идеальная БД ≠ Оптимальный выбор
# ```
#
# **Факторы выбора:**
# - ✅ Наличие экспертизы в команде
# - ✅ Время на внедрение
# - ✅ Стоимость обучения персонала
# - ✅ Бюджет на поддержку
#
# **Вывод:** Возможно, идеальная БД для проекта существует, но выгоднее взять чуть менее идеальную, с которой вы уже можете работать.

# %% [markdown]
# # 🧩 Модульный подход к дизайну
#
# Теперь каждую из компонент рассматриваем как **отдельный модуль**.
#
# ## Что происходит на этом этапе?
#
# - 🔀 Различные сценарии взаимодействия выделяются в **подсервисы**
# - 📨 Появляются **брокеры сообщений** для асинхронного общения
# - 🔐 Можно упомянуть **права доступа** (если есть время на интервью)
#
# ---
#
# ## 🏢 В реальной жизни
#
# Процесс очень похож. Ключевые вопросы:
#
# ### Чеклист проверки компонентов
#
# - [ ] Нужен ли вообще брокер сообщений?
# - [ ] Нужен ли другой частный компонент?
# - [ ] Есть ли люди, которые могут с ним работать?
#
# ### Польза для разных ролей
#
# | Роль | Польза |
# |------|--------|
# | 👔 **Менеджер** | Понять, есть ли что-то лишнее или чего-то не хватает |
# | 💻 **Инженер** | Не получать лишних вопросов от менеджера |

# %% [markdown]
# # ⚡ Масштабирование системы
#
# Когда все модули уже есть, пора поговорить про **масштабирование системы** — устранение избыточности и способы репликации БД и сервисов.
#
# ## Ключевые концепции
#
# Тут возникают такие вещи, как:
#
# - 🔄 **Консистентное хэширование**
# - ⚖️ **Балансировщики нагрузок**
# - 📊 **Масштабирование БД**
# - 🔧 И так далее
#
# ---
#
# ## 🎤 На интервью vs 🏢 В реальной жизни
#
# > ⚠️ **Интересный момент:**
# > На интервью этому этапу уделяют большое внимание, в то время как в жизни везде load balancer'ы **не ставятся**.
#
# ### Когда Load Balancer действительно нужен?
#
# Возникает вопрос выбора реализации:
#
# | Вариант | Плюсы | Минусы |
# |---------|-------|--------|
# | 🖥️ Физические машины | Высокая производительность | Дорого, сложно |
# | 🔧 Nginx как LB | Простота, гибкость | Ограничения производительности |

# %% [markdown]
# # ⚡ Повышение отзывчивости
#
# В разделе нефункциональных требований обычно есть **latency**.
#
# ## На этом этапе разбирается:
#
# - 💾 **Как и что кэшировать?**
# - 📇 **Как индексировать БД?**
# - 🤝 **Действительно ли все хэндшейки нужны?**
#
# ---
#
# ## 🏢 В реальной жизни
#
# > 💰 **Важно:** Кэш — дело дорогое!
#
# ### Процесс принятия решения
#
# ```mermaid
# graph TD
#     A[Нужен ли кэш?] --> B{Latency > 200ms приемлемо?}
#     B -->|Да| C[Кэш не нужен]
#     B -->|Нет| D[Кэш необходим]
#     D --> E[Заложить в расчет нагрузки]
# ```
#
# **Ключевой вопрос:** Возможно, latency > 200 мс для вас подходит?
#
# ✅ Если кэш нужен → он **должен быть заложен** в расчет нагрузки на систему

# %% [markdown]
# # 🔍 Подсистема для поиска
#
# > 📌 Данная тема **часто встречается на интервью**, поэтому было решено добавить ее в курс.
#
# ## Что будет рассмотрено?
#
# В данной лекции будут рассмотрены:
#
# - 🧮 **Полезные алгоритмы**
# - 📊 **Структуры данных**
# - 🎯 **Best practices** для систем поиска

# %% [markdown]
# # 📊 Мониторинг и точки выхода
#
# Успешно завершив предыдущие этапы собеседования, нужно показать, что спроектированный сервис **хорошо работает**.
#
# Очевидно, для этого необходимо мониторить какие-то метрики.
#
# ## Ключевые вопросы
#
# Появляются сразу несколько вопросов:
#
# 1. **Какие** метрики мониторить?
# 2. **Почему** именно они?
#
# ---
#
# ## Критерии выбора метрик
#
# Метрики стоит выбирать такие, которые:
#
# - 💬 **О чем-то говорят** — имеют смысл для бизнеса
# - 🎯 **На которые можно повлиять** — actionable metrics
#
# ---
#
# ## 🎤 На интервью
#
# Достаточно:
# - Обозначить сами метрики
# - Сказать, как они будут мониториться
#
# ---
#
# ## 🏢 В реальной жизни
#
# > ✅ **Главное:** Сервис должен работать!
#
# ### На случай проблем
#
# Если метрики ведут себя не так, нужно понимать: **можем ли быстро понять причины?**
#
# ### Что нужно продумать?
#
# | Аспект | Что делать |
# |--------|-----------|
# | 🏗️ Иерархия метрик | Помогает быстро локализовать проблему |
# | 📈 Системы аналитики | Определить, какие будут использоваться |
# | 📊 Сбор данных | Продумать процесс сбора и хранения |

# %% [markdown]
# # 🃏 Козыри в рукаве
#
# Вероятно, вы — **специалист некоей области**. По окончании собеседования можно показать свои глубокие знания и уточнить какие-то подробности дизайна.
#
# ## 🎤 Стратегия для интервью
#
# Если после собеседования останется время:
#
# ```
# ✅ Ранее указали требования
# ✅ Условились обговорить только основную часть
# → Можно описать решение для одного из отложенных пунктов
# ```
#
# Это покажет:
# - 🎯 Вашу глубину знаний
# - 💡 Способность думать наперед
# - 🔧 Практический опыт
#
# ---
#
# ## 🏢 В реальной жизни
#
# ### После написания дизайн дока
#
# Нужно **ждать отзывов** от читающих его коллег.
#
# ### Как реагировать на фидбек?
#
# | Тип критики | Действие |
# |-------------|----------|
# | ✅ **Адекватная критика** | Повод внести изменения |
# | ❌ **Топят за технологии без аргументов** | К такому лучше не прислушиваться |
#
# > 💡 **Правило:** Ценность имеют только **аргументированные** отзывы!
